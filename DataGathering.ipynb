# %% [markdown]
# ## Data Gathering through API

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Getting the API KEY

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=05112875e11e9a401f212de984fe206b&langage=en-US&page=1')

# %% [markdown]
# ### Taking the required columns for the model

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# %%
df.head()
# Out:
#     id                     title release_date  \
# 0  278  The Shawshank Redemption   1994-09-23
# 1  238             The Godfather   1972-03-14
# 2  240     The Godfather Part II   1974-12-20
# 3  424          Schindler's List   1993-12-15
# 4  389              12 Angry Men   1957-04-10
#
#                                             overview  popularity  vote_average
# 0  Imprisoned in the 1940s for the double murder ...     166.113         8.700
# 1  Spanning the years 1945 to 1955, a chronicle o...     181.091         8.689
# 2  In the continuing saga of the Corleone crime f...      98.193         8.600
# 3  The true story of how businessman Oskar Schind...      81.671         8.567
# 4  The defense and the prosecution have rested an...      59.776         8.500

# %%
df
# Out:
#         id                                          title release_date  \
# 0      278                       The Shawshank Redemption   1994-09-23
# 1      238                                  The Godfather   1972-03-14
# 2      240                          The Godfather Part II   1974-12-20
# 3      424                               Schindler's List   1993-12-15
# 4      389                                   12 Angry Men   1957-04-10
# 5      129                                  Spirited Away   2001-07-20
# 6    19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 7      155                                The Dark Knight   2008-07-16
# 8      497                                 The Green Mile   1999-12-10
# 9   496243                                       Parasite   2019-05-30
# 10     680                                   Pulp Fiction   1994-09-10
# 11  372058                                     Your Name.   2016-08-26
# ...

# %% [markdown]
# ### Get a data from page 5

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=05112875e11e9a401f212de984fe206b&langage=en-US&page=5')

# %%
df1 = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# %%
df1
# Out:
#          id                                     title release_date  \
# 0     29259                                   Le Trou   1960-03-18
# 1     10376                        The Legend of 1900   1998-10-28
# 2       670                                    Oldboy   2003-11-21
# 3    630566                                    Clouds   2020-10-09
# 4    632632                                     Given   2020-08-22
# 5      8587                             The Lion King   1994-06-24
# 6     25237                              Come and See   1985-10-17
# 7   1160164              TAYLOR SWIFT | THE ERAS TOUR   2023-10-13
# 8    447362                            Life in a Year   2020-11-27
# 9    527641                           Five Feet Apart   2019-03-14
# 10   299534                         Avengers: Endgame   2019-04-24
# 11   508965                                     Klaus   2019-11-08
# 12   283566    Evangelion: 3.0+1.0 Thrice Upon a Time   2021-03-08
# ...

# %%
df1.shape
# Out:
# (20, 6)

# %%
df1.to_csv('movies.csv')

# %%
df1
# Out:
#          id                                     title release_date  \
# 0     29259                                   Le Trou   1960-03-18
# 1     10376                        The Legend of 1900   1998-10-28
# 2       670                                    Oldboy   2003-11-21
# 3    630566                                    Clouds   2020-10-09
# 4    632632                                     Given   2020-08-22
# 5      8587                             The Lion King   1994-06-24
# 6     25237                              Come and See   1985-10-17
# 7   1160164              TAYLOR SWIFT | THE ERAS TOUR   2023-10-13
# 8    447362                            Life in a Year   2020-11-27
# 9    527641                           Five Feet Apart   2019-03-14
# 10   299534                         Avengers: Endgame   2019-04-24
# 11   508965                                     Klaus   2019-11-08
# 12   283566    Evangelion: 3.0+1.0 Thrice Upon a Time   2021-03-08
# ...

# %%
df.to_csv('movies_Page1.csv')

# %%
df
# Out:
#         id                                          title release_date  \
# 0      278                       The Shawshank Redemption   1994-09-23
# 1      238                                  The Godfather   1972-03-14
# 2      240                          The Godfather Part II   1974-12-20
# 3      424                               Schindler's List   1993-12-15
# 4      389                                   12 Angry Men   1957-04-10
# 5      129                                  Spirited Away   2001-07-20
# 6    19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 7      155                                The Dark Knight   2008-07-16
# 8      497                                 The Green Mile   1999-12-10
# 9   496243                                       Parasite   2019-05-30
# 10     680                                   Pulp Fiction   1994-09-10
# 11  372058                                     Your Name.   2016-08-26
# ...
